# %% [markdown]
# # Rookie Projection Pipeline
# This notebook demonstrates using the `RookieProjectionPipeline` class to build projections for an NFL draft class.

# %%
import sys
sys.path.append('../src')

from rookie_projection_pipeline import RookieProjectionPipeline

# %%
pipeline = RookieProjectionPipeline(season=2024)
results = pipeline.run()
results[['pfr_player_name','position','tier','boom_metric']].head()
# Out:
#     pfr_player_name position tier  boom_metric
#      Caleb Williams       QB Boom    17.942197
#      Jayden Daniels       QB Boom    27.315946
#          Drake Maye       QB Boom    12.726820
# Marvin Harrison Jr.       WR Bust          NaN
#             Joe Alt       OL Bust          NaN

# %% [markdown]
# To save the results to a CSV file, pass `save_csv=True` when running the pipeline:

# %%
pipeline.run(save_csv=True)
